# %%
# !nvidia-smi

import os
HOME = os.getcwd()
# Out:
# Fri Apr  5 10:43:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# change "/content/gdrive/MyDrive/"  to "/mydrive"
# !ln -s /content/gdrive/MyDrive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
__LINKS__ = {
    'garbage': 'https://drive.google.com/drive/folders/10hBPl81rYAMX6NQY7BIuTLgxzKZd_iMQ?usp=sharing'
}

# %%
# !mkdir garbage
# !unzip /content/gdrive/MyDrive/garbage/garbage.zip -d garbage
# !rm -r garbage/__MACOSX/
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: garbage/train/labels/plastic46_jpg.rf.6e5a4af70be148025287f642187115ac.txt
#  extracting: garbage/train/labels/plastic46_jpg.rf.df743c4ec18c7b76673baf24c8ca2bcf.txt
#  extracting: garbage/train/labels/plastic471_jpg.rf.09160e91e00bfdc55629db797e478d54.txt
#  extracting: garbage/train/labels/plastic471_jpg.rf.3ca72e38e1fa26d9d430b4c84dd8ed8c.txt
#  extracting: garbage/train/labels/plastic472_jpg.rf.1c974d45aaeba0d2c8f1d5f7d441fab8.txt
#  extracting: garbage/train/labels/plastic472_jpg.rf.3714f9a230e12734c823ee2cc857cfe1.txt
#  extracting: garbage/train/labels/plastic473_jpg.rf.8e2e21103bce4b24c1f6d8a9d94642c5.txt
#  extracting: garbage/train/labels/plastic473_jpg.rf.9fa1ffd9f035caf947bd2642a53f7e61.txt
#  extracting: garbage/train/labels/plastic474_jpg.rf.15cc74d1da1bf076e6be062392c08956.txt
#  extracting: garbage/train/labels/plastic474_jpg.rf.db81aa255a78e1da87ddb323217eca32.txt
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics --quiet

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.7/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/garbage/data.yaml epochs=3 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 223MB/s]
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/garbage.pt data=/content/garbage/data.yaml
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/garbage/valid/labels.cache... 2098 images, 0 backgrounds, 0 corrupt: 100% 2098/2098 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 132/132 [00:57<00:00,  2.31it/s]
#                    all       2098      18916      0.453      0.379      0.384      0.232
#          BIODEGRADABLE       2098      13637      0.633      0.493      0.547       0.27
#              CARDBOARD       2098       1292      0.613      0.407      0.476      0.321
#                  GLASS       2098       2380      0.631      0.617      0.647      0.442
#                  METAL       2098       1360      0.508      0.411      0.423      0.248
#                  PAPER       2098         33     0.0113     0.0606     0.0199     0.0197
# ...

# %%
# !yolo predict model=/content/garbage.pt source=/content/paper27.jpg
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843234 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/paper27.jpg: 480x640 1 PAPER, 123.5ms
# Speed: 6.6ms preprocess, 123.5ms inference, 724.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/garbage.pt source=/content/biological22.jpg
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843234 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/biological22.jpg: 416x640 2 BIODEGRADABLEs, 123.2ms
# Speed: 3.5ms preprocess, 123.2ms inference, 576.8ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/garbage.pt source=/content/green-glass32.jpg
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843234 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/green-glass32.jpg: 320x640 5 GLASSs, 4 PLASTICs, 112.0ms
# Speed: 2.8ms preprocess, 112.0ms inference, 527.9ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/garbage.pt source=/content/metal39.jpg
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843234 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/metal39.jpg: 480x640 1 GLASS, 139.4ms
# Speed: 4.3ms preprocess, 139.4ms inference, 871.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/garbage.pt source=/content/Predict/metal3.jpg
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843234 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/Predict/metal3.jpg: 448x640 2 GLASSs, 236.6ms
# Speed: 4.6ms preprocess, 236.6ms inference, 856.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
